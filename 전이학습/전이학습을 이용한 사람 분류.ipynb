# %%
# 한글 폰트 설치하기 (꼭! 설치가 완료되면 [런타임 다시 시작]을 누르고 다시 실행하기)
# !apt install fonts-nanum -y

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정하기
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
matplotlib.font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 2s (3,913 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155685 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
# 필요한 라이브러리 설치하기

# %%
# !git clone https://github.com/ndb796/bing_image_downloader
# Out:
# Cloning into 'bing_image_downloader'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 86 (delta 17), reused 10 (delta 10), pack-reused 64
# Unpacking objects: 100% (86/86), done.

# %% [markdown]
# # 이미지 크롤링으로 이미지 수집

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader


directory_list = [
    './custom_dataset/train/',
    './custom_dataset/test/',
]

# 초기 디렉토리 만들기
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)

# 수집한 이미지를 학습 데이터와 평가 데이터로 구분하는 함수
def dataset_split(query, train_cnt):
    # 학습 및 평가 데이터셋 디렉토리 만들기
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
    # 학습 및 평가 데이터셋 준비하기
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %%
query = '마동석'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 이미지 다운로드 (https://img.hankyung.com/photo/201904/03.18208318.1.jpg)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (http://img.etoday.co.kr/pto_db/2018/04/20180402120558_1200699_600_818.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (http://cdnimage.dailian.co.kr/news/201810/news_1540799498_748189_m_1.jpg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F992C20335A0A0E513B)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F992C20335A0A0E513B
# [Error] HTTP Error 403: Forbidden
# #4 이미지 다운로드 (https://image.ytn.co.kr/osen/2017/11/20160613_1465781770_47067700_1.jpg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (http://image.ytn.co.kr/osen/2017/09/20170830_1504062661_26340500_1.jpg)
# #5 파일 다운로드가 완료되었습니다.
# ...

# %%
query = '김종국'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/997BB03B5AB79FA50C)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F997AB64A5AB7A0DF0E)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F997AB64A5AB7A0DF0E
# [Error] HTTP Error 403: Forbidden
# #2 이미지 다운로드 (http://res.heraldm.com/content/image/2015/04/08/20150408001319_p.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (https://file.mk.co.kr/meet/2016/11/image_readtop_2016_769378_1478218877.jpg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/99C0A0475A93533412)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (https://i.smalljoys.me/2018/06/kim-jong-kuk-to-send-an-army-national-meritorious-application_9o8y0ag3i9ak4co816wd.jpg?resize=700%2C1132&amp;ssl=1&amp;strip=all)
# ...

# %%
query = '이병헌'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 이미지 다운로드 (http://img.newspim.com/news/2020/01/20/2001201559284710.jpg)
# [Info] Issue getting: http://img.newspim.com/news/2020/01/20/2001201559284710.jpg
# [Error] <urlopen error [Errno -2] Name or service not known>
# #1 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/992074395E31B68F2C)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FbW4NqD%2FbtqyOmC9Vzr%2Fhtagzg8JA9xGcD8J7M21G1%2Fimg.png)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FbW4NqD%2FbtqyOmC9Vzr%2Fhtagzg8JA9xGcD8J7M21G1%2Fimg.png
# [Error] HTTP Error 403: Forbidden
# #2 이미지 다운로드 (http://image.cine21.com/resize/cine21/person/2019/1218/14_31_57__5df9b9cdda65a[W680-].jpg)
# #2 파일 다운로드가 완료되었습니다.
# ...

# %% [markdown]
# # 경로지정

# %%
import os
import numpy as np
from PIL import Image

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')

# %%
base_dir='/content/custom_dataset'

train_dir=os.path.join(base_dir,'train')
test_dir=os.path.join(base_dir,'test')

# %%
train_kim_dir=os.path.join(train_dir,'김종국')
train_ma_dir=os.path.join(train_dir,'마동석')
train_lee_dir=os.path.join(train_dir,'이병헌')

test_kim_dir=os.path.join(test_dir,'김종국')
test_ma_dir=os.path.join(test_dir,'마동석')
test_lee_dir=os.path.join(test_dir,'이병헌')

# %%
#리스트담기
train_kim_fnames=os.listdir(train_kim_dir)
train_ma_fnames=os.listdir(train_ma_dir)
train_lee_fnames=os.listdir(train_lee_dir)
print(train_lee_fnames[:5])

test_kim_fnames=os.listdir(test_kim_dir)
test_ma_fnames=os.listdir(test_ma_dir)
test_lee_fnames=os.listdir(test_lee_dir)
print(test_ma_fnames[:5])
# Out:
# ['image_21.jpg', 'image_23.jpg', 'image_33.jpg', 'image_37.jpg', 'image_7.jpg']
# ['image_24.jpg', 'image_9.jpg', 'image_14.jpg', 'image_18.jpg', 'image_15.jpg']

# %%
print(len(train_kim_fnames))
print(len(train_ma_fnames))
print(len(train_lee_fnames))

print(len(test_kim_fnames))
print(len(test_ma_fnames))
print(len(test_lee_fnames))
# Out:
# 30
# 30
# 30
# 10
# 10
# 10

# %% [markdown]
# # 전처리/데이터셋

# %%
img_width=250
img_height=250

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator #ImageDataGenerator는 이미지를 읽어올 때 rescale을 통해 자동으로 정규화시켜준다.

train_data_gen=ImageDataGenerator(rescale=1./255,
                                  rotation_range=10,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  shear_range=0.1,
                                  zoom_range=0.1)

test_data_gen=ImageDataGenerator(rescale=1./255)


train_data=train_data_gen.flow_from_directory(train_dir,
                                              batch_size=32,
                                              color_mode='rgb',
                                              shuffle=True,
                                              class_mode='sparse',#sparse 정답이 one-hot encoding방식으로 정의된다.
                                              target_size=(img_width,img_height)
                                              )
#각 경로 train_dir에서 32개씩 categorical모드로 color이미지에 위 ImageDataGenerator를 이용해 다양하게 이미지를 옆으로도 돌리고 가로 세로도 늘리고 등등해서 읽어들인다는걸 알 수 있음
test_data=test_data_gen.flow_from_directory(test_dir,
                                            batch_size=32,
                                            color_mode='rgb',
                                            shuffle=True,
                                            class_mode='sparse',
                                            target_size=(img_width,img_height)
                                            )
# Out:
# Found 90 images belonging to 3 classes.
# Found 30 images belonging to 3 classes.

# %%
#정답확인(y값)
print(train_data.class_indices.items())

print(test_data.class_indices.items())
# Out:
# dict_items([('김종국', 0), ('마동석', 1), ('이병헌', 2)])
# dict_items([('김종국', 0), ('마동석', 1), ('이병헌', 2)])

# %% [markdown]
# # 모델만들기

# %%
import tensorflow as tf

tf.__version__

from tensorflow.keras import datasets, layers, models
from keras.preprocessing import image
from keras.engine.sequential import Sequential
from tensorflow import keras
from keras import regularizers
from tensorflow.keras.applications import MobileNet, Xception, ResNet50, InceptionV3

# %%
#사전학습모델 불러오기
base_model=ResNet50(weights='imagenet', include_top=False, input_shape=(img_width,img_height,3))
# Out:
# ...
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
#특징 추출기

base_model.trainable=False

base_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 250, 250, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 125, 125, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 125, 125, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 125, 125, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 127, 127, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 63, 63, 64)   0           ['pool1_pad[0][0]']
#
# ...

# %%
from tensorflow.keras.layers import Dense, Dropout, Input
model=models.Sequential()
model.add(base_model)

model.add(layers.GlobalAveragePooling2D())

#새로운 분류기
model.add(layers.Flatten())
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dropout(0.3))   
model.add(layers.Dense(3, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(2e-5), metrics='accuracy')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 16)                32784
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 3)                 51
#
# ...
# Total params: 23,620,547
# Trainable params: 32,835
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from datetime import datetime
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

save_file_name='./마동석,김종국,이병헌 분류기.h5'

checkpoint=ModelCheckpoint(save_file_name,
                           monitor='val_loss',
                           verbose=2,
                           save_best_only=True,
                           mode='auto'
                           )
earlystopping=EarlyStopping(monitor='val_loss',
                            patience=10
                            )

# %%
history=model.fit(train_data,
                  epochs=30,
                  validation_data=test_data,
                  callbacks=[checkpoint, earlystopping]
                  )
# Out:
# Epoch 1/30
# 3/3 [==============================] - ETA: 0s - loss: 1.3714 - accuracy: 0.3667
# Epoch 1: val_loss improved from inf to 1.24855, saving model to ./마동석,김종국,이병헌 분류기.h5
# 3/3 [==============================] - 8s 2s/step - loss: 1.3714 - accuracy: 0.3667 - val_loss: 1.2486 - val_accuracy: 0.3333
# Epoch 2/30
# 3/3 [==============================] - ETA: 0s - loss: 1.3933 - accuracy: 0.3444
# Epoch 2: val_loss improved from 1.24855 to 1.24015, saving model to ./마동석,김종국,이병헌 분류기.h5
# 3/3 [==============================] - 3s 1s/step - loss: 1.3933 - accuracy: 0.3444 - val_loss: 1.2401 - val_accuracy: 0.3333
# Epoch 3/30
# 3/3 [==============================] - ETA: 0s - loss: 1.4480 - accuracy: 0.2556
# Epoch 3: val_loss improved from 1.24015 to 1.23144, saving model to ./마동석,김종국,이병헌 분류기.h5
# 3/3 [==============================] - 3s 1s/step - loss: 1.4480 - accuracy: 0.2556 - val_loss: 1.2314 - val_accuracy: 0.3333
# Epoch 4/30
# ...

# %%
#정확도
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

#loss 
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range=range(30)

#acc 확인
plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.plot(epochs_range, acc, label='train acc')
plt.plot(epochs_range, val_acc, label='test acc')
plt.legend(loc='lower right')
plt.title('train vs test acc')

#loss 확인
plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='train loss')
plt.plot(epochs_range, val_loss, label='val loss')
plt.legend(loc='lower right')
plt.title('train vs test loss')
# Out:
# Text(0.5, 1.0, 'train vs test loss')

# %%
#test데이터 정확도 확인
test_loss, test_acc = model.evaluate(test_data,verbose=2)#verbose는 그냥 출력문을 어떤식으로 보여줄까 묻는거 0은 출력문 안보여줌 1은 반만 2는 전체 다 출력

print('\n테스트 정확도:', test_acc)
print('\n테스트 손실값"',test_loss)
# Out:
# 1/1 - 1s - loss: 1.1994 - accuracy: 1.0000 - 1s/epoch - 1s/step
#
# 테스트 정확도: 1.0
#
# 테스트 손실값" 1.1994222402572632

# %%
ypred=model.predict(test_data)
ypred[:10]
# Out:
# array([[0.5213951 , 0.2098111 , 0.26879373],
#        [0.5594417 , 0.1963326 , 0.24422573],
#        [0.5756669 , 0.19882147, 0.22551164],
#        [0.545776  , 0.19741118, 0.2568128 ],
#        [0.57953644, 0.19946451, 0.22099905],
#        [0.5736901 , 0.19592826, 0.23038161],
#        [0.53634953, 0.20368013, 0.2599703 ],
#        [0.57800156, 0.19504774, 0.22695068],
#        [0.5743276 , 0.19386084, 0.23181161],
#        [0.5463136 , 0.20019045, 0.25349593]], dtype=float32)

# %% [markdown]
# # 시각화

# %%
from tensorflow.keras.applications.imagenet_utils import decode_predictions
import cv2

def pred_img(img, i):
  plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
  
  plt.axis('off')
  plt.show()

  img_resized=cv2.resize(img, (img_width, img_height))
  pred=model.predict(img_resized.reshape([1, img_height, img_width, 3]))
  print(pred[0])

  if(pred[0][0]>pred[0][1] and pred[0][0]>pred[0][2]):
    print('마동석')
  elif(pred[0][1]>pred[0][0] and pred[0][1]>pred[0][2]):
    print('이병헌')
  else:
    print('김종국')

# %%
#이미지 확인
img=[]
for name in test_kim_fnames[:15]:
  img_data=cv2.imread(test_kim_dir+'/'+name)
  img.append(img_data)
for j,data in enumerate(img):
  pred_img(data,j)
# Out:
# [0.5915407  0.36457676 0.0438826 ]
# 마동석
# [0.23484485 0.2903697  0.47478545]
# 김종국
# [0.47992966 0.34666684 0.17340344]
# 마동석
# [0.6215088  0.35495654 0.02353468]
# 마동석
# [0.5012037 0.2900253 0.208771 ]
# 마동석
# [0.5152663  0.24733414 0.23739956]
# 마동석
# [0.23484485 0.2903697  0.47478545]
# 김종국
# [0.59813064 0.31966552 0.08220387]
# 마동석
# [0.44365704 0.44157562 0.11476735]
# 마동석
# [0.5539031  0.29598236 0.15011457]
# 마동석

# %%
pred = model.predict(test_data)
print(pred.shape)
# Out:
# (30, 3)

# %%
import matplotlib.pyplot as plt

class_names = ['김종국', '마동석', '이병헌'] 

plt.figure(figsize=(12,12))

for pos in range(len(pred)):
  plt.subplot(4,4,pos+1)
  plt.axis('off')

  pred_str=class_names[np.argmax(pred[pos])]

  plt.title('pred : '+pred_str)

  plt.imshow(test_data[pos])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:706: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.array(x, subok=True, copy=copy)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-b59a57c6ee68> in <module>
#      13   plt.title('pred : '+pred_str)
#      14
# ---> 15   plt.imshow(test_data[pos])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
# ...
